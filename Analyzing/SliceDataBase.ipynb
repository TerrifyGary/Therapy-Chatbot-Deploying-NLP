# %%
import sqlite3
import pandas as pd
# Create your connection.
cnx = sqlite3.connect('../Scraping/Data/FilteredArticles.db')
df = pd.read_sql_query("SELECT * FROM FilteredArticles", cnx)

# %%
df
# Out:
#              id              title  \
# 0     238636602         普男我曾經被正妹追過
# 1     238643904  從小被爸媽看不起 現在終於被看見了
# 2     238644415        21歲的我 終於破處了
# 3     238644302        我發給肇事者一則長訊息
# 4     238639768          騙說要結婚真的很爛
# ...         ...                ...
# 2220  238909228         Wootalk 維修
# 2221  238909223               怎麼辦⋯
# 2222  238909211         家庭陰影造就現在的我
# 2223  238909178          PCR到底准不准啊
# 2224  238909107                 專題
#
#                                                 content
# 0     本魯長的普通 身高也不高\n但曾經被一個正妹追過\n她身高比我高一個頭吧 \n很有氣質感覺像...
# 1     文很長～\n\n我有一個還算會讀書的姐姐 \n從小到我大學期間總是被爸媽認為比不上我姐\n高...
# 2     從出生到現在的我只有交過一任女友，但那任是國中交的，所以會做的情侶事情很單純就親親抱抱而已，...
# 3     （文長！）去年4月發生一場車禍\n應該算是滿嚴重的吧！\n右手韌帶斷了3根，其實車禍發生當下...
# 4     雖然我這邊不是因為搞到人盡皆知才難以收場\n但我真的要奉勸各位姐妹\n不要聽男友說要結婚就直...
# ...                                                 ...
# 2220                                             怎麼又要修🥲
# 2221                                                😫😫😫
# 2222  第一次發文，排版請見諒，文章內容會有點長\n只是想要透過發文來緩解自己的情緒\n-\n小的時...
# 2223  我不知道發在什麼版比較正常\n\n如題\n我上週六（5/14）快篩第一次陽性（第一條很不明顯...
# 2224          專題要找組員討論一起做\n去問\n人家說，不要問我\n滾\n\n是你，你會怎麼做。
#
# [2225 rows x 3 columns]

# %%
length = df.shape[0]
length
# Out:
# 2225

# %%
df['content'][10]
# Out:
# '剛剛去全聯購物\n正要結帳時，排隊的人在我的前面有三人，快要結完帳的阿姨、正要結帳的大嬸、一個大叔。\n\n大叔突然離開隊伍，我就自然而然地往前補。\n過了一會大叔回來說：「我剛剛排這裡。」（指著我前面）\n我：你已經離開隊伍了，這樣就不算有在排隊。\n大叔：誒不是我只離開一下下耶。\n我：可是你已經離開隊伍了，你自己問店員這樣子行不行。\n大叔：我只離開 一、下、下。(眼神開始逐漸變兇惡)\n大嬸：他剛剛確實是排在我後面我可以作證。(一臉囂張得意貌，又不關她的事是在囂張什麼)\n大叔：哇小姐你真的很計較耶，離開一下下也不行喔？?? \r如果你計較的話我再去排後面ㄏㄚˋ。\n我：...\n大叔：（突然開始大聲）你會計較嗎？？ ㄏㄚˋ？ㄏㄚˋ？？？（凶神惡煞貌）\n\n因為我是自己去全聯，晚上一個女生落單真的超怕回程被打或被砍，不想跟他直接起衝突直接無視他的對話，想說他ㄏㄚˋ夠就會滾了。沒有！！！他就擠進來？？？\n\n正當我內心的火山正要爆發的時候，一個店員突然走進隔壁的櫃台，對我招手🙋🏻\u200d♂️：來這裡結帳。\r\n我就帥氣的籃子一提，閃去隔壁結帳。\n我結完的時候大嬸還在結（她的那個店員比較老動作也比較慢）。\n最後我比那兩個78早離場，還拋給大叔一個得意的眼神（大叔整個愣在原地傻眼）\r\n瀟灑離場。\n\n雖然店員應該不是有意要幫我削減兩個奧客的銳氣（還是其實店員他都看到了？）\n但我還是很感謝他，不然我今天應該會氣很久😂😂'

# %%
import jieba.analyse
def jiebaSlice(content):
    words = jieba.posseg.cut(content)
    slicedWords = []
    for word, flag in words:
        slicedWords.append(word)
    return slicedWords

# %%
sentence = "前幾天在學校附近的超市買東西"
jieba_result_sentence = jiebaSlice(sentence)
jieba_result_sentence
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/hk/mq7wdy2953z7gw87361tc3hw0000gn/T/jieba.cache
# Loading model cost 0.968 seconds.
# Prefix dict has been built successfully.
# ['前', '幾天', '在', '學校', '附近', '的', '超市', '買', '東西']

# %%
jieba_result_article = jiebaSlice(df['content'][10])
jieba_result_article
# Out:
# ['剛剛',
#  '去',
#  '全',
#  '聯購',
#  '物',
#  '\n',
#  '正要',
#  '結帳',
#  '時',
#  '，',
#  '排隊',
#  '的',
#  '人',
#  '在',
#  '我',
#  '的',
#  '前面',
#  '有',
#  '三',
#  '人',
#  '，',
#  '快要',
#  '結完',
#  '帳',
#  '的',
#  '阿姨',
#  '、',
#  '正要',
#  '結帳',
#  '的',
#  '大嬸',
#  '、',
#  '一個',
#  '大叔',
#  '。',
#  '\n',
#  '\n',
#  '大叔',
#  '突然',
#  '離開',
#  '隊伍',
#  '，',
#  '我',
#  '就',
#  '自然而然',
#  '地',
#  '往前',
#  '補',
#  '。',
#  '\n',
#  '過',
#  '了',
#  '一會',
#  '大叔',
#  '回來',
#  '說',
#  '：',
#  '「',
#  '我',
#  '剛剛',
#  '排',
#  '這裡',
#  '。',
#  '」',
#  '（',
#  '指著',
#  '我',
#  '前面',
#  '）',
#  '\n',
#  '我',
#  '：',
#  '你',
#  '已經',
#  '離開',
#  '隊伍',
#  '了',
#  '，',
#  '這樣',
#  '就',
#  '不算',
#  '有',
#  '在',
#  '排隊',
#  '。',
#  '\n',
#  '大叔',
#  '：',
#  '誒',
#  '不是',
#  '我',
#  '只',
#  '離開',
#  '一下下',
#  '耶',
#  '。',
#  '\n',
#  '我',
#  '：',
#  '可是',
#  '你',
#  '已經',
#  '離開',
#  '隊伍',
#  '了',
#  '，',
#  '你',
#  '自己',
#  '問',
#  '店員',
#  '這樣',
#  '子',
#  '行不行',
#  '。',
#  '\n',
#  '大叔',
#  '：',
#  '我',
#  '只',
#  '離開',
#  ' ',
#  '一',
#  '、',
#  '下',
#  '、',
#  '下',
#  '。',
#  '(',
#  '眼神',
#  '開始',
#  '逐漸',
#  '變',
#  '兇惡',
#  ')',
#  '\n',
#  '大嬸',
#  '：',
#  '他',
#  '剛剛',
#  '確實',
#  '是排',
#  '在',
#  '我',
#  '後',
#  '面',
#  '我',
#  '可以',
#  '作證',
#  '。',
#  '(',
#  '一臉',
#  '囂張',
#  '得意',
#  '貌',
#  '，',
#  '又',
#  '不關',
#  '她',
#  '的',
#  '事',
#  '是',
#  '在',
#  '囂張',
#  '什麼',
#  ')',
#  '\n',
#  '大叔',
#  '：',
#  '哇',
#  '小姐',
#  '你',
#  '真的',
#  '很計較',
#  '耶',
#  '，',
#  '離開',
#  '一下下',
#  '也',
#  '不行',
#  '喔',
#  '？',
#  '?',
#  '?',
#  ' ',
#  '\r',
#  '如果',
#  '你',
#  '計',
#  '較',
#  '的話',
#  '我',
#  '再',
#  '去',
#  '排',
#  '後',
#  '面',
#  'ㄏ',
#  'ㄚ',
#  'ˋ',
#  '。',
#  '\n',
#  '我',
#  '：',
#  '...',
#  '\n',
#  '大叔',
#  '：',
#  '（',
#  '突然',
#  '開始',
#  '大聲',
#  '）',
#  '你',
#  '會',
#  '計較',
#  '嗎',
#  '？',
#  '？',
#  ' ',
#  'ㄏ',
#  'ㄚ',
#  'ˋ',
#  '？',
#  'ㄏ',
#  'ㄚ',
#  'ˋ',
#  '？',
#  '？',
#  '？',
#  '（',
#  '凶神',
#  '惡',
#  '煞貌',
#  '）',
#  '\n',
#  '\n',
#  '因為',
#  '我',
#  '是',
#  '自己',
#  '去',
#  '全聯',
#  '，',
#  '晚上',
#  '一個',
#  '女生',
#  '落單',
#  '真的',
#  '超怕',
#  '回程',
#  '被',
#  '打',
#  '或',
#  '被',
#  '砍',
#  '，',
#  '不想',
#  '跟',
#  '他',
#  '直接',
#  '起',
#  '衝突',
#  '直接',
#  '無視',
#  '他',
#  '的',
#  '對話',
#  '，',
#  '想',
#  '說',
#  '他',
#  'ㄏ',
#  'ㄚ',
#  'ˋ',
#  '夠',
#  '就',
#  '會',
#  '滾',
#  '了',
#  '。',
#  '沒有',
#  '！',
#  '！',
#  '！',
#  '他',
#  '就',
#  '擠',
#  '進來',
#  '？',
#  '？',
#  '？',
#  '\n',
#  '\n',
#  '正',
#  '當',
#  '我',
#  '內心',
#  '的',
#  '火山',
#  '正要',
#  '爆發',
#  '的',
#  '時候',
#  '，',
#  '一個',
#  '店員',
#  '突然',
#  '走進',
#  '隔壁',
#  '的',
#  '櫃台',
#  '，',
#  '對',
#  '我',
#  '招手',
#  '🙋',
#  '🏻',
#  '\u200d',
#  '♂',
#  '️',
#  '：',
#  '來',
#  '這裡',
#  '結帳',
#  '。',
#  '\r\n',
#  '我',
#  '就',
#  '帥氣',
#  '的',
#  '籃子',
#  '一',
#  '提',
#  '，',
#  '閃去',
#  '隔壁',
#  '結帳',
#  '。',
#  '\n',
#  '我',
#  '結完',
#  '的',
#  '時候',
#  '大嬸',
#  '還',
#  '在',
#  '結',
#  '（',
#  '她',
#  '的',
#  '那個',
#  '店員',
#  '比較',
#  '老動作',
#  '也',
#  '比',
#  '較慢',
#  '）',
#  '。',
#  '\n',
#  '最',
#  '後',
#  '我',
#  '比',
#  '那',
#  '兩個',
#  '78',
#  '早',
#  '離場',
#  '，',
#  '還',
#  '拋',
#  '給',
#  '大叔',
#  '一個',
#  '得意',
#  '的',
#  '眼神',
#  '（',
#  '大叔',
#  '整個',
#  '愣',
#  '在',
#  '原地',
#  '傻眼',
#  '）',
#  '\r\n',
#  '瀟灑',
#  '離場',
#  '。',
#  '\n',
#  '\n',
#  '雖然',
#  '店員',
#  '應該',
#  '不是',
#  '有意',
#  '要',
#  '幫',
#  '我',
#  '削減',
#  '兩個',
#  '奧客',
#  '的',
#  '銳氣',
#  '（',
#  '還是',
#  '其實',
#  '店員',
#  '他',
#  '都',
#  '看到',
#  '了',
#  '？',
#  '）',
#  '\n',
#  '但',
#  '我',
#  '還',
#  '是',
#  '很',
#  '感謝',
#  '他',
#  '，',
#  '不然',
#  '我',
#  '今天',
#  '應該',
#  '會氣',
#  '很',
#  '久',
#  '😂',
#  '😂']

# %%
import os
import sys
from ckiptagger import data_utils, construct_dictionary, WS, POS, NER

def ckipSlice(content):
    # Download data
    # 下面這邊的，可以想清楚再下載沒關係，因為真的有點大 XDD
    # data_utils.download_data("./") 

    # Load model without GPU
    # 啊如果，真的載下來了，記得把路徑改成 ./data
    ws = WS("/Users/garychen/Documents/ckiptagger/data")
    pos = POS("/Users/garychen/Documents/ckiptagger/data")
    ner = NER("/Users/garychen/Documents/ckiptagger/data")


#     sentence_list = [
#     "前幾天在學校附近的超市買東西，結帳的時候被超帥小鮮肉店員搭訕了，小妹是在亞利桑那州讀研究所的留學生，前陣子人剛到美國決定來個一個人的異國小探險，首先從逛超市開始總之我發現了一間很親切的超市，裡面會進口一些台灣食品，能吃到家鄉的味道對異鄉遊子而言真的是很感動的一件事啊啊但也因為我思鄉的頻率其實挺高的（？所以每個禮拜都會去至少兩次。重點來了，過一陣子我開始發現櫃檯的小帥弟會一直偷瞄我。原本以為是我自己想多了，因為他真的很…帥…。事後想想好像有點衝動，但在這種人生地不熟的地方遇到一個那麼有親切感的帥哥，真的有人會拒絕嗎？？我在台灣的時候是大家眼中那種愛讀書的乖乖女生（其實來美國依然是），而且從小也從來沒有被搭訕過，所以他開口跟我聊天的時候我真的腦袋一片空白。回家後爬了一些Dcard上關於搭訕的經驗談，發現總之態度、搭訕內容還有長相是蠻重要的，剛好小帥弟都符合，所以應該算是一次好的搭訕。"
#     ]
    
    sentence_list = [f'{content}']
    
    word_sentence_list = ws(sentence_list)
    # word_sentence_list = ws(sentence_list, sentence_segmentation=True)
    # word_sentence_list = ws(sentence_list, recommend_dictionary=dictionary)
    # word_sentence_list = ws(sentence_list, coerce_dictionary=dictionary)
    pos_sentence_list = pos(word_sentence_list)
    entity_sentence_list = ner(word_sentence_list, pos_sentence_list)

    # Release model
    del ws
    del pos
    del ner
    
    result = []
    # Show results
    def print_word_pos_sentence(word_sentence, pos_sentence):
        assert len(word_sentence) == len(pos_sentence)
        all_word = []
        for word, pos in zip(word_sentence, pos_sentence):
            # print(f"{word}({pos})", end="\u3000")
            all_word.append(word)
        print()
        return all_word

    for i, sentence in enumerate(sentence_list):
        print()
        # print(f"This is Sentence '{sentence}'")
        result = (print_word_pos_sentence(word_sentence_list[i],  pos_sentence_list[i]))
        # for entity in sorted(entity_sentence_list[i]):
        #     print(entity)

#     print(result)
    
    return result

# %%
ckip_result_sententce = ckipSlice(sentence)
ckip_result_sententce
# Out:
# /usr/local/anaconda3/envs/Awesome/lib/python3.7/site-packages/ckiptagger/model_ws.py:106: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# /usr/local/anaconda3/envs/Awesome/lib/python3.7/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:988: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   partitioner=maybe_partitioner)
# /usr/local/anaconda3/envs/Awesome/lib/python3.7/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:996: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   initializer=initializer)
# 2022-05-12 10:10:04.976618: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/anaconda3/envs/Awesome/lib/python3.7/site-packages/ckiptagger/model_pos.py:56: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# /usr/local/anaconda3/envs/Awesome/lib/python3.7/site-packages/ckiptagger/model_ner.py:57: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# ['前', '幾', '天', '在', '學校', '附近', '的', '超市', '買', '東西']

# %%
ckip_result_article = ckipSlice(df['content'][10])
ckip_result_article
# Out:
# ['剛剛',
#  '去',
#  '全聯',
#  '購物\n',
#  '正',
#  '要',
#  '結帳',
#  '時',
#  '，',
#  '排隊',
#  '的',
#  '人',
#  '在',
#  '我',
#  '的',
#  '前面',
#  '有',
#  '三',
#  '人',
#  '，',
#  '快要',
#  '結完',
#  '帳',
#  '的',
#  '阿姨',
#  '、',
#  '正',
#  '要',
#  '結帳',
#  '的',
#  '大嬸',
#  '、',
#  '一',
#  '個',
#  '大叔',
#  '。',
#  '\n\n',
#  '大叔',
#  '突然',
#  '離開',
#  '隊伍',
#  '，',
#  '我',
#  '就',
#  '自然而然',
#  '地',
#  '往',
#  '前',
#  '補',
#  '。',
#  '\n',
#  '過',
#  '了',
#  '一會',
#  '大叔',
#  '回來',
#  '說',
#  '：',
#  '「',
#  '我',
#  '剛剛',
#  '排',
#  '這裡',
#  '。',
#  '」',
#  '（',
#  '指',
#  '著',
#  '我',
#  '前面',
#  '）',
#  '\n',
#  '我',
#  '：',
#  '你',
#  '已經',
#  '離開',
#  '隊伍',
#  '了',
#  '，',
#  '這樣',
#  '就',
#  '不',
#  '算',
#  '有',
#  '在',
#  '排隊',
#  '。',
#  '\n',
#  '大叔',
#  '：',
#  '誒',
#  '不',
#  '是',
#  '我',
#  '只',
#  '離開',
#  '一下下',
#  '耶。\n',
#  '我',
#  '：',
#  '可是',
#  '你',
#  '已經',
#  '離開',
#  '隊伍',
#  '了',
#  '，',
#  '你',
#  '自己',
#  '問',
#  '店員',
#  '這樣子',
#  '行不行',
#  '。',
#  '\n',
#  '大叔',
#  '：',
#  '我',
#  '只',
#  '離開',
#  ' ',
#  '一',
#  '、',
#  '下',
#  '、',
#  '下',
#  '。',
#  '(',
#  '眼神',
#  '開始',
#  '逐漸',
#  '變',
#  '兇惡',
#  ')',
#  '\n',
#  '大嬸',
#  '：',
#  '他',
#  '剛剛',
#  '確實',
#  '是',
#  '排',
#  '在',
#  '我',
#  '後面',
#  '我',
#  '可以',
#  '作證',
#  '。',
#  '(',
#  '一',
#  '臉',
#  '囂張',
#  '得',
#  '意貌',
#  '，',
#  '又',
#  '不關',
#  '她',
#  '的',
#  '事',
#  '是',
#  '在',
#  '囂張',
#  '什麼',
#  ')',
#  '\n',
#  '大叔',
#  '：',
#  '哇',
#  '小姐',
#  '你',
#  '真的',
#  '很',
#  '計較',
#  '耶',
#  '，',
#  '離開',
#  '一下下',
#  '也',
#  '不行',
#  '喔',
#  '？',
#  '?',
#  '?',
#  ' \r',
#  '如果',
#  '你',
#  '計較',
#  '的話',
#  '我',
#  '再',
#  '去',
#  '排',
#  '後面',
#  'ㄏㄚˋ',
#  '。',
#  '\n',
#  '我',
#  '：',
#  '.',
#  '.',
#  '.',
#  '\n',
#  '大叔',
#  '：',
#  '（',
#  '突然',
#  '開始',
#  '大聲',
#  '）',
#  '你',
#  '會',
#  '計較',
#  '嗎',
#  '？',
#  '？',
#  ' ㄏㄚˋ？ㄏㄚˋ',
#  '？',
#  '？',
#  '？',
#  '（',
#  '凶神',
#  '惡煞貌',
#  '）',
#  '\n\n',
#  '因為',
#  '我',
#  '是',
#  '自己',
#  '去',
#  '全聯',
#  '，',
#  '晚上',
#  '一',
#  '個',
#  '女生',
#  '落單',
#  '真的',
#  '超怕',
#  '回程',
#  '被',
#  '打',
#  '或',
#  '被',
#  '砍',
#  '，',
#  '不',
#  '想',
#  '跟',
#  '他',
#  '直接',
#  '起',
#  '衝突',
#  '直接',
#  '無視',
#  '他',
#  '的',
#  '對話',
#  '，',
#  '想說',
#  '他',
#  'ㄏㄚˋ',
#  '夠',
#  '就',
#  '會',
#  '滾',
#  '了',
#  '。',
#  '沒有',
#  '！',
#  '！',
#  '！',
#  '他',
#  '就',
#  '擠進來',
#  '？',
#  '？',
#  '？',
#  '\n\n',
#  '正當',
#  '我',
#  '內心',
#  '的',
#  '火山',
#  '正',
#  '要',
#  '爆發',
#  '的',
#  '時候',
#  '，',
#  '一',
#  '個',
#  '店員',
#  '突然',
#  '走進',
#  '隔壁',
#  '的',
#  '櫃台',
#  '，',
#  '對',
#  '我',
#  '招手',
#  '🙋🏻',
#  '\u200d♂',
#  '️',
#  '：',
#  '來',
#  '這裡',
#  '結帳',
#  '。',
#  '\r\n',
#  '我',
#  '就',
#  '帥氣',
#  '的',
#  '籃子',
#  '一',
#  '提',
#  '，',
#  '閃去',
#  '隔壁',
#  '結帳',
#  '。',
#  '\n',
#  '我',
#  '結完',
#  '的',
#  '時候',
#  '大嬸',
#  '還',
#  '在',
#  '結',
#  '（',
#  '她',
#  '的',
#  '那',
#  '個',
#  '店員',
#  '比較',
#  '老',
#  '動作',
#  '也',
#  '比較',
#  '慢',
#  '）',
#  '。',
#  '\n',
#  '最後',
#  '我',
#  '比',
#  '那',
#  '兩',
#  '個',
#  '78',
#  '早',
#  '離場',
#  '，',
#  '還',
#  '拋給',
#  '大叔',
#  '一',
#  '個',
#  '得意',
#  '的',
#  '眼神',
#  '（',
#  '大叔',
#  '整',
#  '個',
#  '愣',
#  '在',
#  '原地',
#  '傻眼',
#  '）',
#  '\r\n',
#  '瀟灑',
#  '離場',
#  '。',
#  '\n\n',
#  '雖然',
#  '店員',
#  '應該',
#  '不',
#  '是',
#  '有意',
#  '要',
#  '幫',
#  '我',
#  '削減',
#  '兩',
#  '個',
#  '奧客',
#  '的',
#  '銳氣',
#  '（',
#  '還是',
#  '其實',
#  '店員',
#  '他',
#  '都',
#  '看到',
#  '了',
#  '？',
#  '）',
#  '\n',
#  '但',
#  '我',
#  '還是',
#  '很',
#  '感謝',
#  '他',
#  '，',
#  '不然',
#  '我',
#  '今天',
#  '應該',
#  '會',
#  '氣',
#  '很',
#  '久',
#  '😂',
#  '😂']

# %%
[[x,jieba_result_article.count(x)] for x in set(ckip_result_article)]
# Out:
# [['你', 6],
#  ['不然', 1],
#  ['行不行', 1],
#  ['兇惡', 1],
#  ['但', 1],
#  ['已經', 2],
#  ['滾', 1],
#  [')', 2],
#  ['小姐', 1],
#  ['來', 1],
#  ['大嬸', 3],
#  ['比', 2],
#  ['全聯', 1],
#  ['其實', 1],
#  ['確實', 1],
#  ['感謝', 1],
#  ['櫃台', 1],
#  ['無視', 1],
#  ['結完', 2],
#  ['一下下', 2],
#  ['。', 14],
#  ['招手', 1],
#  ['都', 1],
#  ['得意', 2],
#  ['突然', 3],
#  ['！', 3],
#  ['往', 0],
#  ['如果', 1],
#  ['削減', 1],
#  ['ㄏㄚˋ', 0],
#  ['「', 1],
#  ['隊伍', 3],
#  ['早', 1],
#  ['不行', 1],
#  ['整', 0],
#  ['😂', 2],
#  ['這樣子', 0],
#  ['落單', 1],
#  ['那', 1],
#  ['說', 2],
#  ['、', 4],
#  ['作證', 1],
#  ['大聲', 1],
#  ['一會', 1],
#  ['今天', 1],
#  ['，', 15],
#  ['他', 7],
#  ['不', 0],
#  ['自然而然', 1],
#  ['慢', 0],
#  ['砍', 1],
#  ['三', 1],
#  ['這裡', 2],
#  ['籃子', 1],
#  ['隔壁', 2],
#  ['可以', 1],
#  ['🙋🏻', 0],
#  ['爆發', 1],
#  ['剛剛', 3],
#  ['時候', 2],
#  ['久', 1],
#  ['惡煞貌', 0],
#  ['還', 3],
#  ['正當', 0],
#  ['直接', 2],
#  ['個', 0],
#  ['下', 2],
#  ['動作', 0],
#  ['\r\n', 2],
#  ['(', 2],
#  ['結', 1],
#  ['晚上', 1],
#  ['衝突', 1],
#  ['傻眼', 1],
#  ['逐漸', 1],
#  ['得', 0],
#  ['瀟灑', 1],
#  ['過', 1],
#  ['補', 1],
#  ['回程', 1],
#  ['排隊', 2],
#  ['後面', 0],
#  ['?', 2],
#  ['耶', 2],
#  ['想說', 0],
#  ['沒有', 1],
#  ['\n\n', 0],
#  ['什麼', 1],
#  ['回來', 1],
#  ['結帳', 4],
#  ['離開', 6],
#  ['打', 1],
#  ['因為', 1],
#  ['嗎', 1],
#  ['事', 1],
#  ['對話', 1],
#  ['我', 21],
#  ['帳', 1],
#  ['正', 1],
#  ['氣', 0],
#  ['）', 6],
#  ['很', 2],
#  ['\u200d♂', 0],
#  ['開始', 2],
#  ['人', 2],
#  ['愣', 1],
#  ['快要', 1],
#  ['去', 3],
#  ['只', 2],
#  ['雖然', 1],
#  ['算', 0],
#  ['老', 0],
#  ['指', 0],
#  ['原地', 1],
#  ['.', 0],
#  ['或', 1],
#  ['起', 1],
#  ['\n', 21],
#  ['計較', 1],
#  [' ', 3],
#  ['看到', 1],
#  ['最後', 0],
#  ['著', 0],
#  ['被', 2],
#  ['擠進來', 0],
#  ['也', 2],
#  ['超怕', 1],
#  ['臉', 0],
#  ['可是', 1],
#  ['對', 1],
#  ['內心', 1],
#  ['閃去', 1],
#  ['女生', 1],
#  ['銳氣', 1],
#  ['又', 1],
#  ['一', 2],
#  ['有意', 1],
#  ['再', 1],
#  ['凶神', 1],
#  ['變', 1],
#  ['奧客', 1],
#  ['想', 1],
#  ['購物\n', 0],
#  ['的話', 1],
#  ['自己', 2],
#  ['有', 2],
#  ['提', 1],
#  ['大叔', 9],
#  ['火山', 1],
#  ['幫', 1],
#  ['是', 3],
#  ['前', 0],
#  ['真的', 2],
#  ['耶。\n', 0],
#  ['兩', 0],
#  ['️', 1],
#  ['哇', 1],
#  ['排', 2],
#  ['應該', 2],
#  ['在', 6],
#  ['前面', 2],
#  ['她', 2],
#  [' \r', 0],
#  ['？', 11],
#  ['阿姨', 1],
#  [' ㄏㄚˋ？ㄏㄚˋ', 0],
#  ['帥氣', 1],
#  ['囂張', 2],
#  ['會', 2],
#  ['78', 1],
#  ['」', 1],
#  ['還是', 1],
#  ['比較', 1],
#  ['離場', 2],
#  ['：', 10],
#  ['問', 1],
#  ['這樣', 2],
#  ['拋給', 0],
#  ['就', 5],
#  ['要', 1],
#  ['意貌', 0],
#  ['（', 6],
#  ['店員', 5],
#  ['時', 1],
#  ['眼神', 2],
#  ['誒', 1],
#  ['喔', 1],
#  ['走進', 1],
#  ['地', 1],
#  ['的', 14],
#  ['夠', 1],
#  ['跟', 1],
#  ['不關', 1],
#  ['了', 5]]

# %%
[[x,ckip_result_article.count(x)] for x in set(ckip_result_article)]
# Out:
# [['你', 6],
#  ['不然', 1],
#  ['行不行', 1],
#  ['兇惡', 1],
#  ['但', 1],
#  ['已經', 2],
#  ['滾', 1],
#  [')', 2],
#  ['小姐', 1],
#  ['來', 1],
#  ['大嬸', 3],
#  ['比', 1],
#  ['全聯', 2],
#  ['其實', 1],
#  ['確實', 1],
#  ['感謝', 1],
#  ['櫃台', 1],
#  ['無視', 1],
#  ['結完', 2],
#  ['一下下', 2],
#  ['。', 13],
#  ['招手', 1],
#  ['都', 1],
#  ['得意', 1],
#  ['突然', 3],
#  ['！', 3],
#  ['往', 1],
#  ['如果', 1],
#  ['削減', 1],
#  ['ㄏㄚˋ', 2],
#  ['「', 1],
#  ['隊伍', 3],
#  ['早', 1],
#  ['不行', 1],
#  ['整', 1],
#  ['😂', 2],
#  ['這樣子', 1],
#  ['落單', 1],
#  ['那', 2],
#  ['說', 1],
#  ['、', 4],
#  ['作證', 1],
#  ['大聲', 1],
#  ['一會', 1],
#  ['今天', 1],
#  ['，', 15],
#  ['他', 7],
#  ['不', 4],
#  ['自然而然', 1],
#  ['慢', 1],
#  ['砍', 1],
#  ['三', 1],
#  ['這裡', 2],
#  ['籃子', 1],
#  ['隔壁', 2],
#  ['可以', 1],
#  ['🙋🏻', 1],
#  ['爆發', 1],
#  ['剛剛', 3],
#  ['時候', 2],
#  ['久', 1],
#  ['惡煞貌', 1],
#  ['還', 2],
#  ['正當', 1],
#  ['直接', 2],
#  ['個', 8],
#  ['下', 2],
#  ['動作', 1],
#  ['\r\n', 2],
#  ['(', 2],
#  ['結', 1],
#  ['晚上', 1],
#  ['衝突', 1],
#  ['傻眼', 1],
#  ['逐漸', 1],
#  ['得', 1],
#  ['瀟灑', 1],
#  ['過', 1],
#  ['補', 1],
#  ['回程', 1],
#  ['排隊', 2],
#  ['後面', 2],
#  ['?', 2],
#  ['耶', 1],
#  ['想說', 1],
#  ['沒有', 1],
#  ['\n\n', 4],
#  ['什麼', 1],
#  ['回來', 1],
#  ['結帳', 4],
#  ['離開', 6],
#  ['打', 1],
#  ['因為', 1],
#  ['嗎', 1],
#  ['事', 1],
#  ['對話', 1],
#  ['我', 21],
#  ['帳', 1],
#  ['正', 3],
#  ['氣', 1],
#  ['）', 6],
#  ['很', 3],
#  ['\u200d♂', 1],
#  ['開始', 2],
#  ['人', 2],
#  ['愣', 1],
#  ['快要', 1],
#  ['去', 3],
#  ['只', 2],
#  ['雖然', 1],
#  ['算', 1],
#  ['老', 1],
#  ['指', 1],
#  ['原地', 1],
#  ['.', 3],
#  ['或', 1],
#  ['起', 1],
#  ['\n', 11],
#  ['計較', 3],
#  [' ', 1],
#  ['看到', 1],
#  ['最後', 1],
#  ['著', 1],
#  ['被', 2],
#  ['擠進來', 1],
#  ['也', 2],
#  ['超怕', 1],
#  ['臉', 1],
#  ['可是', 1],
#  ['對', 1],
#  ['內心', 1],
#  ['閃去', 1],
#  ['女生', 1],
#  ['銳氣', 1],
#  ['又', 1],
#  ['一', 7],
#  ['有意', 1],
#  ['再', 1],
#  ['凶神', 1],
#  ['變', 1],
#  ['奧客', 1],
#  ['想', 1],
#  ['購物\n', 1],
#  ['的話', 1],
#  ['自己', 2],
#  ['有', 2],
#  ['提', 1],
#  ['大叔', 9],
#  ['火山', 1],
#  ['幫', 1],
#  ['是', 5],
#  ['前', 1],
#  ['真的', 2],
#  ['耶。\n', 1],
#  ['兩', 2],
#  ['️', 1],
#  ['哇', 1],
#  ['排', 3],
#  ['應該', 2],
#  ['在', 6],
#  ['前面', 2],
#  ['她', 2],
#  [' \r', 1],
#  ['？', 10],
#  ['阿姨', 1],
#  [' ㄏㄚˋ？ㄏㄚˋ', 1],
#  ['帥氣', 1],
#  ['囂張', 2],
#  ['會', 3],
#  ['78', 1],
#  ['」', 1],
#  ['還是', 2],
#  ['比較', 2],
#  ['離場', 2],
#  ['：', 10],
#  ['問', 1],
#  ['這樣', 1],
#  ['拋給', 1],
#  ['就', 5],
#  ['要', 4],
#  ['意貌', 1],
#  ['（', 6],
#  ['店員', 5],
#  ['時', 1],
#  ['眼神', 2],
#  ['誒', 1],
#  ['喔', 1],
#  ['走進', 1],
#  ['地', 1],
#  ['的', 14],
#  ['夠', 1],
#  ['跟', 1],
#  ['不關', 1],
#  ['了', 5]]

# %%
from emoji import UNICODE_EMOJI
def isEmoji(content):
    if not content:
        return False
    if u"\U0001F600" <= content and content <= u"\U0001F64F":
        return True
    elif u"\U0001F300" <= content and content <= u"\U0001F5FF":
        return True
    elif u"\U0001F680" <= content and content <= u"\U0001F6FF":
        return True
    elif u"\U0001F1E0" <= content and content <= u"\U0001F1FF":
        return True
    else:
        return False
    
def listFilter(inputList):    
    temp = []
    emoji = []
    for x in inputList:
        if x.isalpha():
            temp.append(x)
        if isEmoji(x) == True:
            emoji.append(x)
    return temp,emoji

# %%
isEmoji('😄')
# Out:
# True

# %%
listFilter(ckip_result_article)
# Out:
# (['剛剛',
#   '去',
#   '全聯',
#   '正',
#   '要',
#   '結帳',
#   '時',
#   '排隊',
#   '的',
#   '人',
#   '在',
#   '我',
#   '的',
#   '前面',
#   '有',
#   '三',
#   '人',
#   '快要',
#   '結完',
#   '帳',
#   '的',
#   '阿姨',
#   '正',
#   '要',
#   '結帳',
#   '的',
#   '大嬸',
#   '一',
#   '個',
#   '大叔',
#   '大叔',
#   '突然',
#   '離開',
#   '隊伍',
#   '我',
#   '就',
#   '自然而然',
#   '地',
#   '往',
#   '前',
#   '補',
#   '過',
#   '了',
#   '一會',
#   '大叔',
#   '回來',
#   '說',
#   '我',
#   '剛剛',
#   '排',
#   '這裡',
#   '指',
#   '著',
#   '我',
#   '前面',
#   '我',
#   '你',
#   '已經',
#   '離開',
#   '隊伍',
#   '了',
#   '這樣',
#   '就',
#   '不',
#   '算',
#   '有',
#   '在',
#   '排隊',
#   '大叔',
#   '誒',
#   '不',
#   '是',
#   '我',
#   '只',
#   '離開',
#   '一下下',
#   '我',
#   '可是',
#   '你',
#   '已經',
#   '離開',
#   '隊伍',
#   '了',
#   '你',
#   '自己',
#   '問',
#   '店員',
#   '這樣子',
#   '行不行',
#   '大叔',
#   '我',
#   '只',
#   '離開',
#   '一',
#   '下',
#   '下',
#   '眼神',
#   '開始',
#   '逐漸',
#   '變',
#   '兇惡',
#   '大嬸',
#   '他',
#   '剛剛',
#   '確實',
#   '是',
#   '排',
#   '在',
#   '我',
#   '後面',
#   '我',
#   '可以',
#   '作證',
#   '一',
#   '臉',
#   '囂張',
#   '得',
#   '意貌',
#   '又',
#   '不關',
#   '她',
#   '的',
#   '事',
#   '是',
#   '在',
#   '囂張',
#   '什麼',
#   '大叔',
#   '哇',
#   '小姐',
#   '你',
#   '真的',
#   '很',
#   '計較',
#   '耶',
#   '離開',
#   '一下下',
#   '也',
#   '不行',
#   '喔',
#   '如果',
#   '你',
#   '計較',
#   '的話',
#   '我',
#   '再',
#   '去',
#   '排',
#   '後面',
#   'ㄏㄚˋ',
#   '我',
#   '大叔',
#   '突然',
#   '開始',
#   '大聲',
#   '你',
#   '會',
#   '計較',
#   '嗎',
#   '凶神',
#   '惡煞貌',
#   '因為',
#   '我',
#   '是',
#   '自己',
#   '去',
#   '全聯',
#   '晚上',
#   '一',
#   '個',
#   '女生',
#   '落單',
#   '真的',
#   '超怕',
#   '回程',
#   '被',
#   '打',
#   '或',
#   '被',
#   '砍',
#   '不',
#   '想',
#   '跟',
#   '他',
#   '直接',
#   '起',
#   '衝突',
#   '直接',
#   '無視',
#   '他',
#   '的',
#   '對話',
#   '想說',
#   '他',
#   'ㄏㄚˋ',
#   '夠',
#   '就',
#   '會',
#   '滾',
#   '了',
#   '沒有',
#   '他',
#   '就',
#   '擠進來',
#   '正當',
#   '我',
#   '內心',
#   '的',
#   '火山',
#   '正',
#   '要',
#   '爆發',
#   '的',
#   '時候',
#   '一',
#   '個',
#   '店員',
#   '突然',
#   '走進',
#   '隔壁',
#   '的',
#   '櫃台',
#   '對',
#   '我',
#   '招手',
#   '來',
#   '這裡',
#   '結帳',
#   '我',
#   '就',
#   '帥氣',
#   '的',
#   '籃子',
#   '一',
#   '提',
#   '閃去',
#   '隔壁',
#   '結帳',
#   '我',
#   '結完',
#   '的',
#   '時候',
#   '大嬸',
#   '還',
#   '在',
#   '結',
#   '她',
#   '的',
#   '那',
#   '個',
#   '店員',
#   '比較',
#   '老',
#   '動作',
#   '也',
#   '比較',
#   '慢',
#   '最後',
#   '我',
#   '比',
#   '那',
#   '兩',
#   '個',
#   '早',
#   '離場',
#   '還',
#   '拋給',
#   '大叔',
#   '一',
#   '個',
#   '得意',
#   '的',
#   '眼神',
#   '大叔',
#   '整',
#   '個',
#   '愣',
#   '在',
#   '原地',
#   '傻眼',
#   '瀟灑',
#   '離場',
#   '雖然',
#   '店員',
#   '應該',
#   '不',
#   '是',
#   '有意',
#   '要',
#   '幫',
#   '我',
#   '削減',
#   '兩',
#   '個',
#   '奧客',
#   '的',
#   '銳氣',
#   '還是',
#   '其實',
#   '店員',
#   '他',
#   '都',
#   '看到',
#   '了',
#   '但',
#   '我',
#   '還是',
#   '很',
#   '感謝',
#   '他',
#   '不然',
#   '我',
#   '今天',
#   '應該',
#   '會',
#   '氣',
#   '很',
#   '久'],
#  ['🙋🏻', '😂', '😂'])

# %%
listFilter(jieba_result_article)
# Out:
# (['剛剛',
#   '去',
#   '全',
#   '聯購',
#   '物',
#   '正要',
#   '結帳',
#   '時',
#   '排隊',
#   '的',
#   '人',
#   '在',
#   '我',
#   '的',
#   '前面',
#   '有',
#   '三',
#   '人',
#   '快要',
#   '結完',
#   '帳',
#   '的',
#   '阿姨',
#   '正要',
#   '結帳',
#   '的',
#   '大嬸',
#   '一個',
#   '大叔',
#   '大叔',
#   '突然',
#   '離開',
#   '隊伍',
#   '我',
#   '就',
#   '自然而然',
#   '地',
#   '往前',
#   '補',
#   '過',
#   '了',
#   '一會',
#   '大叔',
#   '回來',
#   '說',
#   '我',
#   '剛剛',
#   '排',
#   '這裡',
#   '指著',
#   '我',
#   '前面',
#   '我',
#   '你',
#   '已經',
#   '離開',
#   '隊伍',
#   '了',
#   '這樣',
#   '就',
#   '不算',
#   '有',
#   '在',
#   '排隊',
#   '大叔',
#   '誒',
#   '不是',
#   '我',
#   '只',
#   '離開',
#   '一下下',
#   '耶',
#   '我',
#   '可是',
#   '你',
#   '已經',
#   '離開',
#   '隊伍',
#   '了',
#   '你',
#   '自己',
#   '問',
#   '店員',
#   '這樣',
#   '子',
#   '行不行',
#   '大叔',
#   '我',
#   '只',
#   '離開',
#   '一',
#   '下',
#   '下',
#   '眼神',
#   '開始',
#   '逐漸',
#   '變',
#   '兇惡',
#   '大嬸',
#   '他',
#   '剛剛',
#   '確實',
#   '是排',
#   '在',
#   '我',
#   '後',
#   '面',
#   '我',
#   '可以',
#   '作證',
#   '一臉',
#   '囂張',
#   '得意',
#   '貌',
#   '又',
#   '不關',
#   '她',
#   '的',
#   '事',
#   '是',
#   '在',
#   '囂張',
#   '什麼',
#   '大叔',
#   '哇',
#   '小姐',
#   '你',
#   '真的',
#   '很計較',
#   '耶',
#   '離開',
#   '一下下',
#   '也',
#   '不行',
#   '喔',
#   '如果',
#   '你',
#   '計',
#   '較',
#   '的話',
#   '我',
#   '再',
#   '去',
#   '排',
#   '後',
#   '面',
#   'ㄏ',
#   'ㄚ',
#   'ˋ',
#   '我',
#   '大叔',
#   '突然',
#   '開始',
#   '大聲',
#   '你',
#   '會',
#   '計較',
#   '嗎',
#   'ㄏ',
#   'ㄚ',
#   'ˋ',
#   'ㄏ',
#   'ㄚ',
#   'ˋ',
#   '凶神',
#   '惡',
#   '煞貌',
#   '因為',
#   '我',
#   '是',
#   '自己',
#   '去',
#   '全聯',
#   '晚上',
#   '一個',
#   '女生',
#   '落單',
#   '真的',
#   '超怕',
#   '回程',
#   '被',
#   '打',
#   '或',
#   '被',
#   '砍',
#   '不想',
#   '跟',
#   '他',
#   '直接',
#   '起',
#   '衝突',
#   '直接',
#   '無視',
#   '他',
#   '的',
#   '對話',
#   '想',
#   '說',
#   '他',
#   'ㄏ',
#   'ㄚ',
#   'ˋ',
#   '夠',
#   '就',
#   '會',
#   '滾',
#   '了',
#   '沒有',
#   '他',
#   '就',
#   '擠',
#   '進來',
#   '正',
#   '當',
#   '我',
#   '內心',
#   '的',
#   '火山',
#   '正要',
#   '爆發',
#   '的',
#   '時候',
#   '一個',
#   '店員',
#   '突然',
#   '走進',
#   '隔壁',
#   '的',
#   '櫃台',
#   '對',
#   '我',
#   '招手',
#   '來',
#   '這裡',
#   '結帳',
#   '我',
#   '就',
#   '帥氣',
#   '的',
#   '籃子',
#   '一',
#   '提',
#   '閃去',
#   '隔壁',
#   '結帳',
#   '我',
#   '結完',
#   '的',
#   '時候',
#   '大嬸',
#   '還',
#   '在',
#   '結',
#   '她',
#   '的',
#   '那個',
#   '店員',
#   '比較',
#   '老動作',
#   '也',
#   '比',
#   '較慢',
#   '最',
#   '後',
#   '我',
#   '比',
#   '那',
#   '兩個',
#   '早',
#   '離場',
#   '還',
#   '拋',
#   '給',
#   '大叔',
#   '一個',
#   '得意',
#   '的',
#   '眼神',
#   '大叔',
#   '整個',
#   '愣',
#   '在',
#   '原地',
#   '傻眼',
#   '瀟灑',
#   '離場',
#   '雖然',
#   '店員',
#   '應該',
#   '不是',
#   '有意',
#   '要',
#   '幫',
#   '我',
#   '削減',
#   '兩個',
#   '奧客',
#   '的',
#   '銳氣',
#   '還是',
#   '其實',
#   '店員',
#   '他',
#   '都',
#   '看到',
#   '了',
#   '但',
#   '我',
#   '還',
#   '是',
#   '很',
#   '感謝',
#   '他',
#   '不然',
#   '我',
#   '今天',
#   '應該',
#   '會氣',
#   '很',
#   '久'],
#  ['🙋', '🏻', '😂', '😂'])
